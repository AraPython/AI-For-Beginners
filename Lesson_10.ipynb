# %%
! pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
a = ['a','b','c','d','e']
print(a)
print("".join(a))
# Out:
# ['a', 'b', 'c', 'd', 'e']
# abcde

# %%
import re
def clean_arabic_wors(s):
  return "".join(re.findall('[\u0621-\u064A\u0660-\u0669 ]', s))

# %%
print(clean_arabic_wors("رونالدو"))
# Out:
# رونالدو

# %%
import numpy as np

data=[
      """رونالدو يحسم قراره ويطلب الرحيل عن مانشستر يونايتد تابع لندن - رويترز نشر في: 02 يوليو ,2022: 08:05 م GST آخر تحديث: 02 يوليو ,2022: 09:18 م GST ذكرت صحيفة "تايمز" البريطانية أن كريستيانو رونالدو طلب من إدارة مانشستر يونايتد السماح له بالرحيل عن النادي، إذا حصل على عرض يرضيه خلال فترة الانتقالات الجارية. وأضافت الصحيفة أن المهاجم البرتغالي البالغ عمره 37 عاما يرغب بشدة في اللعب في دوري أبطال أوروبا خلال باقي مسيرته. ولم يتأهل يونايتد للعب في دوري الأبطال في الموسم المقبل. وتابعت أن رونالدو شارك في 19 موسما متتاليا من دوري أبطال أوروبا منذ مغادرته فريق سبورتنغ لشبونة إلى الكرة الإنجليزية في صيف عام 2003، ولم يلعب مطلقا في الدوري الأوروبي وهي البطولة التي سيشارك فيها مانشستر يونايتد بعدما احتل المركز السادس في الدوري الإنجليزي الموسم الماضي. ويثق النجم البرتغالي في قدرته على قضاء ثلاثة أو أربعة أعوام يستطيع خلالها على اللعب في أعلى مستوى، ويرغب في قضاء تلك الفترة مع فريق يمكنه من خلاله إضافة أرقاما فردية إلى إنجازاته. وأكد مقربون من رونالدو، أنه يحتفظ بمكانة كبيرة واحترام شديد لجماهير مانشستر يونايتد، وبالإضافة إلى الأسباب الرياضية لرحيله عن الفريق، فإن لديه أسبابا شخصية تتمثل في عائلته التي لم تكن سعيدة بالحياة في مدينة مانشستر. وعاد كريستيانو الموسم الماضي إلى مانشستر يونايتد، بعد 12 عاما على رحيله من الفريق ، حيث لعب لريال مدريد الإسباني ويوفنتوس الإيطالي، قبل العودة مجددا إلى "أولد ترافورد".""",
      """الطماطم 4 فوائد مدهشة للطماطم.. لكن لا تفرط في تناولها تابع دبي - العربية.نت نشر في: 03 يوليو ,2022: 11:44 ص GST آخر تحديث: 03 يوليو ,2022: 12:17 م GST الطماطم لا غنى عنها في جميع الوجبات تقريبا، فهي ثمرة غنية ليس فقط من حيث النكهة ولكن أيضا من حيث الفوائد الصحية المحتملة. ومع ذلك، فإن الطماطم ليست للجميع، فهي واحدة من أكثر أنواع الأطعمة المرتبطة بالحساسية الغذائية. فقد تسبب بعض الأعراض الهضمية غير السارة لدى بعض الأشخاص، لكنها أيضا تعتبر "فاكهة" ومن الأطعمة الغنية بمضادات الأكسدة والمليئة بالعديد من الفيتامينات والعناصر الغذائية الأساسية الأخرى. "ضحية مش مجرم".. وسم عن قاتل نيرة أشرف يغضب المصريين مصر "ضحية مش مجرم".. وسم عن قاتل نيرة أشرف يغضب المصريين 1. تحمي البشرة الطماطم مليئة بالكاروتينات، وهو نوع معين من مضادات الأكسدة التي تحمي بشرتك من أضرار أشعة الشمس، وفق خبيرة التغذية إيلينا بارافانتس. 2. تحسن المزاج لا تعمل الطماطم على تعزيز نكهة وجبتك فحسب، بل إنها قد تحسن المزاج أيضا على المدى الطويل. فقد وجدت دراسة أجريت عام 2013 ونشرت في مجلة The Journal of Affective Disorders أن المشاركين الذين تناولوا الطماطم مرتين إلى ست مرات في الأسبوع كانوا أقل عرضة بنسبة 46% للإبلاغ عن أع
]

data2=[]

for idx , row in enumerate(data):
  tokonize = row.split(' ')
  li = [clean_arabic_wors(w) for w in tokonize]
  li2 = [itm for itm in li if len(itm) > 1]
  data2.append(li2)
  # سطر لطباعة عدد الكلمات في النص
print(np.sum([len(x) for x in data2]))
print(li2)
# Out:
# 792
# ...

# %%
print(data2)
# Out:
# [['رونالدو', 'يحسم', 'قراره', 'ويطلب', 'الرحيل', 'عن', 'مانشستر', 'يونايتد', 'تابع', 'لندن', 'رويترز', 'نشر', 'في', 'يوليو', 'آخر', 'تحديث', 'يوليو', 'ذكرت', 'صحيفة', 'تايمز', 'البريطانية', 'أن', 'كريستيانو', 'رونالدو', 'طلب', 'من', 'إدارة', 'مانشستر', 'يونايتد', 'السماح', 'له', 'بالرحيل', 'عن', 'النادي', 'إذا', 'حصل', 'على', 'عرض', 'يرضيه', 'خلال', 'فترة', 'الانتقالات', 'الجارية', 'وأضافت', 'الصحيفة', 'أن', 'المهاجم', 'البرتغالي', 'البالغ', 'عمره', 'عاما', 'يرغب', 'بشدة', 'في', 'اللعب', 'في', 'دوري', 'أبطال', 'أوروبا', 'خلال', 'باقي', 'مسيرته', 'ولم', 'يتأهل', 'يونايتد', 'للعب', 'في', 'دوري', 'الأبطال', 'في', 'الموسم', 'المقبل', 'وتابعت', 'أن', 'رونالدو', 'شارك', 'في', 'موسما', 'متتاليا', 'من', 'دوري', 'أبطال', 'أوروبا', 'منذ', 'مغادرته', 'فريق', 'سبورتنغ', 'لشبونة', 'إلى', 'الكرة', 'الإنجليزية', 'في', 'صيف', 'عام', 'ولم', 'يلعب', 'مطلقا', 'في', 'الدوري', 'الأوروبي', 'وهي', 'البطولة', 'التي', 'سيشارك', 'فيها', 'مانشستر', 'يونايتد', 'بعدما', 'احتل', 'المركز', 'السادس', 'في', 'الدوري'
# ...

# %%
#Data Transformation 
import gensim
model = gensim.models.Word2Vec(
        data2,
        size=150,
        window=10,
        min_count=2,
        workers=10,
        iter=10)
model.save("model")

# %%
import gensim
model = gensim.models.Word2Vec.load("model")

# %%
print(len(model.wv.vocab))
print(model.wv.similarity('مانشستر','رونالدو'))
print(model.wv['رونالدو'] )
# Out:
# 116
# 0.02632405
# [-6.7016116e-04  1.9963186e-03  3.2826974e-03 -1.2254734e-03
#  -1.7251424e-03 -9.2513551e-04 -1.2357718e-03 -3.5193067e-03
#  -2.3127177e-03  2.0823635e-03  1.4798839e-03 -5.8443303e-04
#   3.1392265e-03  2.4229183e-05 -1.3467603e-03  2.4960593e-03
#   1.1372883e-03 -1.3066903e-03  2.4165183e-03 -1.0207511e-03
#   2.5202464e-03 -7.4626856e-05  6.1381288e-05 -2.8384023e-03
#   1.9507548e-03  1.1453871e-03  2.5275571e-03 -2.3182602e-04
#   2.1739670e-03 -1.8342449e-03  3.6872973e-04  2.3502326e-03
#  -3.8567165e-04  5.7680439e-04  2.0210778e-03  1.0386478e-03
#  -2.3039845e-03 -2.4434295e-03  1.0417483e-05  1.4201074e-03
#   1.9740365e-03  1.8375525e-03  1.2547054e-03  3.2396740e-03
#  -1.9599258e-03 -1.9571511e-03 -1.7614603e-03 -1.8848911e-03
#   4.7212307e-04  1.4030627e-03  2.0034241e-03  2.8519710e-03
#  -1.8801788e-03 -3.2692379e-03  1.7271979e-03 -1.8592604e-03
#   1.2470907e-04 -2.8608358e-03  1.4270149e-03 -3.3548623e-03
# ...
