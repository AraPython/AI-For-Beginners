# %%
f = open("/content/TestCSV2.csv", "r")
print(f.readline())
# Out:
# Name,Age,Grad,G

# %%
file_ = open("/content/testCSV1.csv", "r")
for line in file_:
  print(line)
#= open لازم نسكر الملف بعيها 
#والا عند فتح الملف مرة تانية باستخدام برنامج اخر سيعطي ايرور الملف مفتوع و ممنوع التعديل 
file_.close()
# Out:
# Name	Age	Grade	G
#
# Ahmed	22	99	M
#
# Sawsan	22	98	F
#
# Hassan	21	95	M

# %%
with open('/content/testCSV1.csv', "a") as file_:
    lines = f.readlines()
    print(lines)
# Out:
# ['Ahmed,25,85,M\n', 'Ali,22,99,M\n', 'Hanan,25,99,F\n', ',,,\n']

# %% [markdown]
# Mode	Description
#
# 'r'	Open for text file for reading text
#
# 'w'	Open a text file for writing text
#
# 'a'	Open a text file for appending text

# %%
with open('/content/TestCSV3.csv','r', encoding='utf8') as f:
    for line in f:
        print(line)
# Out:
# Name,Age,Grad
#
# علي,25,85
#
# أحمد,22,99
#
# حنان,25,99
#
# سوسن,22,95

# %%
def read_in_chunks(file_object, chunk_size=1024):
    while True:
        data = file_object.read(chunk_size)
        if not data:
            break
        yield data

with open('/content/TestCSV4.csv') as f:
    for piece in read_in_chunks(f):
      print(piece)

# %%
import csv
rows = []
with open("/content/TestCSV2.csv", 'r') as file_:
    csvreader = csv.reader(file_)
    header = next(csvreader)
    for row in csvreader:
        rows.append(row)
print(header)
for row in rows:
  print(row)
# Out:
# ['Name', 'Age', 'Grad', 'G']
# ['Ahmed', '25', '85', 'M']
# ['Ali', '22', '99', 'M']
# ['Hanan', '25', '99', 'F']
# ['', '', '', '']

# %%
header = ['name', 'area', 'country_code2', 'country_code3','','','']
data = [
    ['Albania', 28748, 'AL', 'ALB'],
    ['Algeria', 2381741, 'DZ', 'DZA'],
    ['American Samoa', 199, 'AS', 'ASM'],
    ['Andorra', 555, 'AD', 'AND'],
    ['Angola', 1246700, 'AO', 'AGO'],
    [],
    [],
    []
]

with open('/content/countries.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write multiple rows
    writer.writerows(data)

# %%
fieldnames = ['name', 'area', 'country_code2', 'country_code3','','','','']

# csv data
rows =[
    {'name': 'Albania','area': 28748,'country_code2': 'AL','country_code3': 'ALB'},
    {'name': 'Algeria','area': 2381741,'country_code2': 'DZ','country_code3': 'DZA'},
    {'name': 'American Samoa','area': 199,'country_code2': 'AS','country_code3': 'ASM'}
    {},
    

    ]

with open('/content/countries2.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows)
